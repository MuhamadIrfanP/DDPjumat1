# %%
print("Nama : Muhamad Irfan Pratama")
print("NIM : 0110124025")
print("Rombel : SI08")
print("Asdos : Kak Saya")
# Out:
# Nama : Muhamad Irfan Pratama
# NIM : 0110124025
# Rombel : SI08
# Asdos : Kak Saya
