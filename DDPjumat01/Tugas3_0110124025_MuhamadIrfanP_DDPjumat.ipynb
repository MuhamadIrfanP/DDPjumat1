# %%
nama = "Muhamad Irfan Pratama"
nim = "0110124025"
rombel = "si08"
noTelp = "085714484058"
alamat = "Kab Bogor"

print("Nama:",nama)
print("Nim:",nim)
print("Rombel:",rombel)
print("No Telp:",noTelp)
print("Alamat:",alamat)
# Out:
# Nama: Muhamad Irfan Pratama
# Nim: 0110124025
# Rombel: si08
# No Telp: 085714484058
# Alamat: Kab Bogor

# %%
nama="ahmad fauzil azhim"
nim="0110124169"
rombel="si08"
notlp="085776678241"
alamat="bogor"
print("nama:",nama)
print("nim:",nim)
print("rombel:",rombel)
print("notlp:",notlp)
print("alamat:",alamat)
# Out:
# nama: ahmad fauzil azhim
# nim: 0110124169
# rombel: si08
# notlp: 085776678241
# alamat: bogor

# %%
#input
tb = int(input("Masukan Tinggi Badan:"))

#proses
bbIdeal = (tb-100)-((tb-100) *0.1)

#output
print("Berat badan Ideal saya dengan tinggi badan", tb, "adalah",bbIdeal, "kg",)
# Out:
# Masukan Tinggi Badan:165
# Berat badan Ideal saya dengan tinggi badan 165 adalah 58.5 kg

# %%
#input
celcius = 32

#proses
fahreinheit = (celcius*9/5)+32

#output
print(celcius,"derajat celsius adalah", fahreinheit, "derajat fahreinheit")
# Out:
# 32 derajat celsius adalah 89.6 derajat fahreinheit

# %%
#input
r=int(input("masukan jari-jari tabung"))
t=int(input("masukan tingi tabung"))
#proses
phi=3.14
v=phi*r*r*t
l=2* phi *r*(r+t)
#output
print("volume tabung = ",v)
print("luas tabung =",l)
# Out:
# masukan jari-jari tabung62
# masukan tingi tabung26
# volume tabung =  313824.16
# luas tabung = 34263.68
